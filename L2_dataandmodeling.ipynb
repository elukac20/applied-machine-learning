# %%
import gradio as gr
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# https://www.kaggle.com/datasets/jsphyg/star-wars/data

# %% [markdown]
# (Data and Modelling) Do physical attributes predict whether the characters are going to die
# during the movies that they appear in? Use this Kaggle dataset and let me know! In your modelling
# you should a) pay attention to the structure and the meaning of the data, b) make use of linear
# regression and feed forward neural networks, c) make specific modelling choices (loss,
# optimization, evaluation metrics).

# %%
df = pd.read_csv('./data/characters.csv')

# %%
df['year_died'].unique()
# Out:
# array([34., 35.,  4., nan,  0., 19., 32., 22.,  2., 10.])

# %% [markdown]
# 'nan' implies did not die

# %%
df['died'] = np.where(df['year_died'].isna(), False, True)

# %%
df.head()
# Out:
#    id            name         species  gender  height  weight hair_color  \
# 0   1  Luke Skywalker           Human    Male    1.72    77.0      Blond
# 1   2     Leia Organa           Human  Female    1.50    49.0      Brown
# 2   3     Darth Vader           Human    Male    2.02   136.0        NaN
# 3   4            Yoda  Yoda's species    Male    0.66    17.0      White
# 4   5        Han Solo           Human    Male    1.80    80.0      Brown
#
#   eye_color skin_color  year_born homeworld  year_died  \
# 0      Blue      Light       19.0  Tatooine       34.0
# 1     Brown      Light       19.0  Alderaan       35.0
# 2    Yellow       Pale       41.0  Tatooine        4.0
# 3     Brown      Green      896.0   Unknown        4.0
# 4     Hazel      Light       29.0  Corellia       34.0
#
#                                          description  died
# 0      The main protagonist of the original trilogy.  True
# 1  A leader in the Rebel Alliance and twin sister...  True
# ...

# %% [markdown]
# Relevant physical attributes: species, gender, height, weight, hair_color, eye_color, skin_color

# %% [markdown]
# ## Linear regression + feed forward networks
